# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaustubhc911/Data_Science_Lab/blob/main/Exp_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Code to compute factorial of number
def factorial(n):
    """Calculates the factorial of a non-negative integer n."""
    if n == 0:
        return 1
    else:
        res = 1
        for i in range(1, n + 1):
            res *= i
        return res

# Example usage:
number = 5
result = factorial(number)
print(f"The factorial of {number} is {result}")

# Another example:
number = 0
result = factorial(number)
print(f"The factorial of {number} is {result}")
# Out:
# The factorial of 5 is 120
# The factorial of 0 is 1

# %%
def display_multiplication_table(number, limit=10):
    """Displays the multiplication table for a given number up to a specified limit."""
    print(f"Multiplication Table for {number}:")
    for i in range(1, limit + 1):
        print(f"{number} x {i} = {number * i}")

# Example usage:
num = 7
display_multiplication_table(num)

print("\n") # Add a newline for better separation

# Another example with a different limit:
num = 12
display_multiplication_table(num, limit=5)
# Out:
# Multiplication Table for 7:
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70
#
#
# Multiplication Table for 12:
# 12 x 1 = 12
# 12 x 2 = 24
# 12 x 3 = 36
# 12 x 4 = 48
# 12 x 5 = 60

# %%
def is_odd_or_even(number):
    """Checks if a given number is odd or even."""
    if number % 2 == 0:
        return "Even"
    else:
        return "Odd"

# Example usage:
num1 = 7
print(f"The number {num1} is {is_odd_or_even(num1)}.")

num2 = 10
print(f"The number {num2} is {is_odd_or_even(num2)}.")

num3 = 0
print(f"The number {num3} is {is_odd_or_even(num3)}.")
# Out:
# The number 7 is Odd.
# The number 10 is Even.
# The number 0 is Even.

# %%
def is_palindrome_number(number):
    """Checks if a given number is a palindrome."""
    # Convert the number to a string
    num_str = str(number)
    # Compare the string with its reverse
    return num_str == num_str[::-1]

# Example usage:
num1 = 121
print(f"The number {num1} is a palindrome: {is_palindrome_number(num1)}.")

num2 = 12345
print(f"The number {num2} is a palindrome: {is_palindrome_number(num2)}.")

num3 = 12321
print(f"The number {num3} is a palindrome: {is_palindrome_number(num3)}.")

num4 = -121 # Negative numbers are typically not considered palindromes in this context
print(f"The number {num4} is a palindrome: {is_palindrome_number(num4)}.")
# Out:
# The number 121 is a palindrome: True.
# The number 12345 is a palindrome: False.
# The number 12321 is a palindrome: True.
# The number -121 is a palindrome: False.

# %% [markdown]
# # Task
# Develop a Python-based expert system for student performance analysis. The system should include: a function to collect and validate student inputs (attendance percentage, internal marks, assignment completion, previous semester CGPA, backlogs); a function to initialize the output structure; a rule-based engine (8-10 IF-THEN rules) to determine risk, performance category, mentoring recommendations, and personalized suggestions; a function to display results; and a menu-driven interface with options to input new student data, run 3 sample test cases, or exit. Finally, consolidate all components into a single runnable code cell with a brief summary.

# %% [markdown]
# ## Define Input Collection and Validation
#
# ### Subtask:
# Create a function to securely collect and validate student input parameters: attendance percentage (0-100), internal marks (0-30), assignment completion (yes/no), previous semester CGPA (0-10), and backlogs (yes/no). Implement basic input validation for type and range.

# %% [markdown]
# **Reasoning**:
# I will define the `collect_and_validate_student_data` function that securely collects and validates student input parameters as specified in the instructions, using loops for repeated prompting until valid input is received and returning the validated inputs.

# %%
def collect_and_validate_student_data():
    """Collects and validates student input parameters."""

    # 1. Attendance Percentage (0-100)
    while True:
        try:
            attendance = int(input("Enter attendance percentage (0-100): "))
            if 0 <= attendance <= 100:
                break
            else:
                print("Invalid input. Attendance percentage must be between 0 and 100.")
        except ValueError:
            print("Invalid input. Please enter an integer for attendance percentage.")

    # 2. Internal Marks (0-30)
    while True:
        try:
            internal_marks = int(input("Enter internal marks (0-30): "))
            if 0 <= internal_marks <= 30:
                break
            else:
                print("Invalid input. Internal marks must be between 0 and 30.")
        except ValueError:
            print("Invalid input. Please enter an integer for internal marks.")

    # 3. Assignment Completion (yes/no)
    while True:
        assignment_completion = input("Has assignment completion been done (yes/no)? ").lower()
        if assignment_completion in ['yes', 'no']:
            break
        else:
            print("Invalid input. Please enter 'yes' or 'no'.")

    # 4. Previous Semester CGPA (0.0-10.0)
    while True:
        try:
            cgpa = float(input("Enter previous semester CGPA (0.0-10.0): "))
            if 0.0 <= cgpa <= 10.0:
                break
            else:
                print("Invalid input. CGPA must be between 0.0 and 10.0.")
        except ValueError:
            print("Invalid input. Please enter a valid number for CGPA.")

    # 5. Backlogs (yes/no)
    while True:
        backlogs = input("Does the student have backlogs (yes/no)? ").lower()
        if backlogs in ['yes', 'no']:
            break
        else:
            print("Invalid input. Please enter 'yes' or 'no'.")

    return attendance, internal_marks, assignment_completion, cgpa, backlogs

# Example usage of the function:
print("Please provide student data:")
validated_data = collect_and_validate_student_data()
print("\nValidated Student Data:")
print(f"  Attendance Percentage: {validated_data[0]}%")
print(f"  Internal Marks: {validated_data[1]}")
print(f"  Assignment Completion: {validated_data[2].capitalize()}")
print(f"  Previous Semester CGPA: {validated_data[3]}")
print(f"  Backlogs: {validated_data[4].capitalize()}")
# Out:
# Please provide student data:
